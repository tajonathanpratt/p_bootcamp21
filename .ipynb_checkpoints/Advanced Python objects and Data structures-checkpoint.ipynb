# %%
#advanced numbers

# %%
#hexadecimal
hex(13)
# Out:
# '0xd'

# %%
hex(512)
# Out:
# '0x200'

# %%
bin(12345)
# Out:
# '0b11000000111001'

# %%
2**4
# Out:
# 16

# %%
#also pow for power | 3rd argument calculate mod value

#pow(2,4)

pow(2,4,3)
# Out:
# 1

# %%
#abs for absolute value

abs(-2)
# Out:
# 2

# %%
round(3)
# Out:
# 3

# %%
round(3.5)
# Out:
# 4

# %%
round(3.9)
# Out:
# 4

# %%
#round to 2 decimal places
round(3.14285,2)
# Out:
# 3.14

# %%
#advanced strings

# %%
s='hello world'

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.count('o')
# Out:
# 2

# %%
s.find('o')
# Out:
# 4

# %%
s.center(20,'z')
# Out:
# 'zzzzhello worldzzzzz'

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
s.isalnum()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %%
s.endswith('d')
# Out:
# True

# %%
s[-1]=='d'
# Out:
# True

# %%
s.split('e')
# Out:
# ['h', 'llo world']

# %%
#only separates first not rest
s.partition('e')
# Out:
# ('h', 'e', 'llo world')

# %%
#advanced sets

# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s={1,2,3}

# %%
#copy whole set and save to declared variable
sc=s.copy()

# %%
sc
# Out:
# {1, 2, 3}

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
sc
# Out:
# {1, 2, 3}

# %%
s.difference(sc)
# Out:
# {4}

# %%
s1={1,2,3}
s2={1,4,5}

# %%
#updates the initial set
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 3, 4}

# %%
s.discard(12)
#nothing happens

# %%
s1={1,2,3}
s2={1,2,4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1={1,2}
s2={1,2,4}
s3={5}

# %%
#check is there any null intersection
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.issubset(s2)
# Out:
# True

# %%
#reverse of issubset()
s2.issuperset(s1)
# Out:
# True

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
#opposite of intersection
s1.symmetric_difference(s2)
# Out:
# {4}

# %%
s1.union(s2)
# Out:
# {1, 2, 4}

# %%
s1.update(s2)

# %%
s1
# Out:
# {1, 2, 4}
